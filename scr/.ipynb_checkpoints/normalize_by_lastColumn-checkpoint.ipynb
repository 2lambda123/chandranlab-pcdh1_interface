# %%
import pandas as pd
from os import listdir
from os.path import isfile, join

# %% [markdown]
# Choose either 'competition' or 'neutralization'

# %%
input_type = 'competition'
if not input_type == 'competition' or input_type == 'neutralization':
    print('Error! input_type can only be \'competition\' or \'neutralization\'' )

# %% [markdown]
# Getting the list of files to be processed. These can either be binding elisa or neutralization data

# %%
# getting the right directory based on input_type
compdir = '../input/competition_ELISAs_EC1_mutants'
neutdir = '../input/neutralization_EC1_mutants'
if input_type == 'competition':
    indir = compdir
else:
    indir = neutdir

# listing files in corresponding directory
filelist = []
for f in listdir(indir):
    if not isfile(join(indir, f)):
        continue
    if (not '.xlsx' in f) or (f[0:1] == '~'):
        continue
#     print(f)
    filelist.append(f)
print('Files to normalize: ', len(filelist))
# Out:
# Files to normalize:  17

# %% [markdown]
# Normalize each file and concatenate them

# %%
# set up output file
if input_type == 'competition':
    outfile = '../output/competition_normalized.xlsx'
else:
    outfile = '../output/neutralization_normalized.xlsx'

# normalize
df = pd.DataFrame()
for c, f in enumerate(filelist):
#     if c > 0:
#         break
    print(c, f)
    # Loading excel into dataframe
    df0 = pd.concat(pd.read_excel(indir + '/' + f, sheet_name=None), ignore_index=True)
    # Renaming columns
    df0 = df0.rename(columns={'Unnamed: 0': 'Instance'})
    for col in df0.columns:
#         print(col)
        if isinstance(col, float):
#             print('\tfloat')
            df0 = df0.rename(columns={col: "{:.6f}".format(col)})
#     display(df0)
    # Normalizing
    df1 = df0.copy()
    df1.iloc[:,1:] = df0.iloc[:,1:].div(df0['Control'], axis=0)*100
#     display(df1)
    # Adding to main dataframe
    df1['File'] = f
    df = pd.concat([df, df1])
# df.to_excel('competition_elisa_normalized.xlsx')
df.to_excel(outfile)
# Out:
# 0 EC1-Mapping-CompELISA-Experiment-updated-16.xlsx
# 1 EC1-Mapping-CompELISA-Experiment-updated-6.xlsx
# 2 EC1-Mapping-CompELISA-Experiment-updated-7.xlsx
# 3 EC1-Mapping-CompELISA-Experiment-updated-17.xlsx
# 4 EC1-Mapping-CompELISA-Experiment-updated-10.xlsx
# 5 EC1-Mapping-CompELISA-Experiment-updated-11.xlsx
# 6 EC1-Mapping-CompELISA-Experiment-updated-1.xlsx
# 7 EC1-Mapping-CompELISA-Experiment-updated-2.xlsx
# 8 EC1-Mapping-CompELISA-Experiment-updated-12.xlsx
# 9 EC1-Mapping-CompELISA-Experiment-updated-13.xlsx
# 10 EC1-Mapping-CompELISA-Experiment-updated-3.xlsx
# 11 EC1-Mapping-CompELISA-Experiment-updated-14.xlsx
# 12 EC1-Mapping-CompELISA-Experiment-updated-8.xlsx
# 13 EC1-Mapping-CompELISA-Experiment-updated-4.xlsx
# 14 EC1-Mapping-CompELISA-Experiment-updated-5.xlsx
# 15 EC1-Mapping-CompELISA-Experiment-updated-9.xlsx
# 16 EC1-Mapping-CompELISA-Experiment-updated-15.xlsx

# %%
display(df0)
# Out:
#    Instance         5  1.666667  0.555556  0.185185  0.061728  0.020576  \
# 0        wt  0.216179  0.318813  0.558999  1.033888  1.470840  1.518489
